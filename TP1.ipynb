# %% [markdown]
# {
#   "nbformat": 4,
#   "nbformat_minor": 0,
#   "metadata": {
#     "colab": {
#       "name": "TP1.ipynb",
#       "provenance": [],
#       "collapsed_sections": []
#     },
#     "kernelspec": {
#       "name": "python3",
#       "display_name": "Python 3"
#     },
#     "language_info": {
#       "name": "python"
#     }
#   },
#   "cells": [
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "A1AMQ4p-eUGU"
#       },
#       "source": [
#         "# TP 1 "
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "RoB-Psz6BCdX"
#       },
#       "source": [
#         "Le but de ce TP est de mettre en pratique les notions de classification vues en cours. Un ensemble de données représentant la composition et la provenance d’éclats de verre en fonction de plusieurs paramètres vous est fournie (glass.data). Une description complète des attributs est disponible elle aussi (glass.names). L 'objectif est de comparer la performance de 3 types de classificateurs vu en cours. Ce TP est composé de 6 tâches :\n",
#         " \n",
#         "*   A - Chargement des données - qui consiste à comprendre les données manipulé et à les charger dans dataset cohérent et exploitable\n",
#         "*   B - Visualisation des données - qui consiste à afficher des éléments caractéristiques de répartition des données \n",
#         "*   C - Arbre de décision - qui consiste à créer un classificateur utilisant un arbre de décision\n",
#         "*   D - Classification Bayésienne naïve - qui consiste à créer un classificateur Bayésienne naïf\n",
#         "*   E - K-NN - qui consiste à créer un classificateur par k plus proche voisin\n",
#         "*   F - Évaluation de L'apprentissage - qui consiste à comparer ces classificateur pour déterminer quel est le plus performant\n",
#         " \n",
#         "Ce tp doit être réaliser un utilisant scikit-learn, une librairie python fréquemment utilisée en science des données. (documentation sur https://scikit-learn.org)\n",
#         " \n",
#         "Le corp du tp est donné en python via jupyter\n",
#         " \n",
#         "Le rendu devra contenir :\n",
#         "  - le code\n",
#         "  - les images (si non réalisé avec  jupyter, si jupyter non utilisé)\n",
#         "  - les réponses aux questions dans le code / ou en dehors si non réalisé avec jupyter\n",
#         " \n",
#         "barème :\n",
#         "- Code qui s'exécute correctement (sans erreurs) 10 pts\n",
#         "- A - 15 pts\n",
#         "- B - 15 pts\n",
#         "- C - 15 pts\n",
#         "- D - 15 pts\n",
#         "- E - 15 pts\n",
#         "- F - 15 pts\n",
#         " \n",
#         "Le dépôt doit se faire sur Moodle au **plus tard le vendredi 12 novembre à 23h59**. Les équipes de 2 sont recommandées, aucune équipe de 3 accepté."
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "ssPvnD5v9MOh"
#       },
#       "source": [
#         "# TÂCHE A - Chargement des données"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "m5v1UP0JBAMS"
#       },
#       "source": [
#         "Pour cette tâche, vous devez importer et manipuler les données du fichier glass.data. Vous devez réaliser 4 fonctions :\n",
#         "* Une fonction de chargement\n",
#         "* Une fonction qui permet d'enlever des attributs inutiles (ATTENTION à bien analyser les attributs et à indiquer quelles sont ceux qui pourrait être inutile voir avoir un impact négatif sur l'apprentissage)\n",
#         "* Une fonction qui permet de séparer les données en 2 ensemble (un ensemble d'apprentissage et un ensemble de validation)\n",
#         "* Une fonction qui permet de séparer les attributs et les classes\n",
#         "\n",
#         "\n",
#         "\n",
#         "\n",
#         "\n",
#         "\n",
#         "\n"
#       ]
#     },
#     {
#       "cell_type": "code",
#       "metadata": {
#         "id": "90iye5VrCuL8"
#       },
#       "source": [
#         "# Importer ici toutes les libraries nécessaire au reste du code\n",
#         "import csv"
#       ],
#       "execution_count": null,
#       "outputs": []
#     },
#     {
#       "cell_type": "code",
#       "metadata": {
#         "id": "ttz2Jh2qjS80"
#       },
#       "source": [
#         "# Fonction qui charge les données depuis un fichier\n",
#         "def loadData(file):\n",
#         "  return []\n",
#         "\n",
#         "# Fonction qui retire les collonnes (labels) inutiles, comme par expemple \n",
#         "# l'id de la données d'apprentissage\n",
#         "def removeColumn(dataset):\n",
#         "  return[]\n",
#         "  \n",
#         "\n",
#         "# Fonction qui sépare les données en deus sous ensemble, un emsemble d'entrainement\n",
#         "# et un ensemble de validation (utilisez une séparation 80/20 )\n",
#         "def splitData(data,offset):\n",
#         "  return[[], []] \n",
#         "\n",
#         "# Fonction retire les labels inutiles et séparents les données entre les attibuts \n",
#         "# et les classes\n",
#         "def sliceLabel(dataset):\n",
#         "  X = []\n",
#         "  Y = []\n",
#         "  return[X,Y]\n",
#         "\n",
#         "# Chargez ici les 4 ensembles\n",
#         "dataset = loadData(\"glass.data\")\n",
#         "dataset_training_X = []\n",
#         "dataset_training_Y = []\n",
#         "dataset_validation_X = []\n",
#         "dataset_validation_Y = []\n",
#         "\n",
#         "\n",
#         "\n",
#         "\n"
#       ],
#       "execution_count": null,
#       "outputs": []
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "h0xgbHLt_muD"
#       },
#       "source": [
#         "# TÂCHE B - Visualisation et compréhension des données"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "A6DpAZlzaPZ9"
#       },
#       "source": [
#         "Pour cette tâches expliquez avec vos mots quelles est la nature des données que vous manipulez ici. Affichez la répartition de chacun des attributs pertinents sur un graphe. Determiner une listes d'attributs méritant d'être discrétiser. Pourc hacun de ces attributs, proposer une discretisation et convertissez les données pour la suite du TP. Faite une rapide analyse pour éliminer les données abhérente si il en y a. Justifier votre approche"
#       ]
#     },
#     {
#       "cell_type": "code",
#       "metadata": {
#         "id": "r_6ercwmaPqP"
#       },
#       "source": [
#         "# Fonction qui affiche la répartitions des attributs pertinents\n",
#         "def printLabels(dataset):\n",
#         "  return []\n",
#         "\n",
#         "# Fonction qui discrétise les données pertinentes\n",
#         "def discretData(dataset):\n",
#         "  return []\n",
#         "\n",
#         "printLabels(dataset)\n",
#         "dataset = discretData(dataset)\n",
#         "\n",
#         "\n"
#       ],
#       "execution_count": null,
#       "outputs": []
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "R2KhtbYKgKBi"
#       },
#       "source": [
#         "*Insérer ici votre analyse de données*\n",
#         "\n"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "2y4Wy-fWd20-"
#       },
#       "source": [
#         "*Insérer ici votre analyse du netoyage de données*\n"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "4fg5V9CMACTQ"
#       },
#       "source": [
#         "# TÂCHE C - Arbre de décision"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "ZeY7v2QAaQ_e"
#       },
#       "source": [
#         "Réalisez un arbre de décision à partir des données de glass.data. Affichez sa matrice de confusion. Que pouvez-vous dire sur cet arbre (taille, lisibilité, performances...)?\n",
#         "Réaliser un second arbre en élaguant le premier pour le limiter ent taille à 10 noeuds. Afficher la nouvelle matrice de confusion. Quelles est l'impact sur la performance ?"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "cWzA0ZdLhTWb"
#       },
#       "source": [
#         "*Insérez ici l'analyse du premier arbre*"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "z2F_s3yQhTJG"
#       },
#       "source": [
#         "*Insérer ici l'impact sur la performance*"
#       ]
#     },
#     {
#       "cell_type": "code",
#       "metadata": {
#         "colab": {
#           "base_uri": "https://localhost:8080/"
#         },
#         "id": "j-ROOpXTDMnV",
#         "outputId": "8ef510e7-5bb2-41b9-ab4d-be7138954ddd"
#       },
#       "source": [
#         "# Fonction qui créer et entraine un arbre de décision\n",
#         "def decisionTree(dataset):\n",
#         "  return []\n",
#         "\n",
#         "# Fonction qui génére et affiche une matrice de confusion à partir des données \n",
#         "# de validations\n",
#         "def confusionMatrixTree(tree):\n",
#         "  return []\n",
#         "\n",
#         "# Fonction qui élague un arbre pour le réduire à 10 noeuds \n",
#         "def treePruning(tree):\n",
#         "  return []\n",
#         "\n",
#         "glassTree = []\n",
#         "confusionMatrixTree(glassTree) \n",
#         "glassTreePrune = treePruning(glassTree)\n",
#         "confusionMatrixTree(glassTreePrune) "
#       ],
#       "execution_count": null,
#       "outputs": [
#         {
#           "output_type": "execute_result",
#           "data": {
#             "text/plain": [
#               "[]"
#             ]
#           },
#           "metadata": {},
#           "execution_count": 4
#         }
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "lWaI_WWOALMx"
#       },
#       "source": [
#         "# TÂCHE D - Classification Bayésienne naïve"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "K6jhJp7gh5-1"
#       },
#       "source": [
#         "Pour cette tâche, faîte un classificateur bayésien naïf. Afficher sa matrice de confusion. "
#       ]
#     },
#     {
#       "cell_type": "code",
#       "metadata": {
#         "id": "qLMxgt3PKpmd"
#       },
#       "source": [
#         "# Fonction qui créer et entraine un classificateur bayésien naîf\n",
#         "def bayesianClass(dataset):\n",
#         "  return []\n",
#         "\n",
#         "# Fonction qui génére et affiche une matrice de confusion à partir des données \n",
#         "# de validations\n",
#         "def confusionMatrixBC(bayesianClass):\n",
#         "  return []\n",
#         "\n",
#         "glassBC = []\n",
#         "confusionMatrixBC(glassTree) "
#       ],
#       "execution_count": null,
#       "outputs": []
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "E0EqGvJTARJE"
#       },
#       "source": [
#         "# TÂCHE E - K-NN"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "_xH10ENtiVPB"
#       },
#       "source": [
#         "Pour cette tâche, faîte un classificateur k plus proches voisins. Afficher sa matrice de confusion. Justifié votre choix de valeur de k."
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "AxRpe4gOig82"
#       },
#       "source": [
#         "*Insérer ici le k choisi et sa justification*"
#       ]
#     },
#     {
#       "cell_type": "code",
#       "metadata": {
#         "colab": {
#           "base_uri": "https://localhost:8080/"
#         },
#         "id": "GogJqA9tfN_K",
#         "outputId": "3a5e613f-9489-479b-a5b4-315ddd74050c"
#       },
#       "source": [
#         "# Fonction qui créer un classificateur k-nn\n",
#         "def knnClass(dataset):\n",
#         "  return []\n",
#         "\n",
#         "# Fonction qui génére et affiche une matrice de confusion à partir des données \n",
#         "# de validations\n",
#         "def confusionMatrixknn(bayesianClass):\n",
#         "  return []\n",
#         "\n",
#         "glassknn = []\n",
#         "confusionMatrixknn(glassTree) "
#       ],
#       "execution_count": null,
#       "outputs": [
#         {
#           "output_type": "execute_result",
#           "data": {
#             "text/plain": [
#               "KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',\n",
#               "                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,\n",
#               "                     weights='uniform')"
#             ]
#           },
#           "metadata": {},
#           "execution_count": 34
#         }
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "ZOTvKWUMA1Ua"
#       },
#       "source": [
#         "# TÂCHE F - Évaluation de L'apprentissage"
#       ]
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "ToCnsnK3cUZn"
#       },
#       "source": [
#         "Pour cette tâche vous devrez déterminer quel est le meilleur des 4 classificateurs que vous avez testé. Pour celà générer la courbe ROC de chacun des classificateurs et justifier quel est le meilleur."
#       ]
#     },
#     {
#       "cell_type": "code",
#       "metadata": {
#         "id": "j177K0ObcUsl"
#       },
#       "source": [
#         "# Fonction qui affiche les courbes ROCS\n",
#         "def printROC(tree,BC,knn):\n",
#         "  return []"
#       ],
#       "execution_count": null,
#       "outputs": []
#     },
#     {
#       "cell_type": "markdown",
#       "metadata": {
#         "id": "ogmXJEtzewRG"
#       },
#       "source": [
#         "*Meilleur Classificateur : (insérer votre réponse ici)*"
#       ]
#     }
#   ]
# }
